# %%
import pickle
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines import CoxPHFitter

import time
import datetime

print(datetime.datetime.now())
# Out:
# 2023-01-17 10:21:02.074601

# %%
path_data = 'data/d20220201/'

# INPUTS
fn_finalSave = path_data + 'featuresAndMeta_s20220720.p'
fn_predictionsTraining  = path_data + 'predictionsTraining_binary_s20220704.xlsx'
fn_predictionsValidation = path_data + 'predictionsValidation_binary_s20220704.xlsx'
fn_predictionsTraining_3g  = path_data + 'predictionsTraining_s20220302.xlsx'
fn_predictionsValidation_3g = path_data + 'predictionsValidation_s20220519.xlsx'
fn_forLorenz = path_data + 'radipopPredictions_toLorenz.csv'

# OUTPUTS
fn_figure_km = 'f_kapMeier_s20220718.svg'
fn_figure_km_big = 'f_kapMeier_big_s20220718.svg'

plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

# %%
with open(fn_finalSave, "rb") as input_file:
    dict_data = pickle.load(input_file)

dict_data.keys()
# Out:
# dict_keys(['df_rawFeatures_training', 'df_rawFeatures_validation', 'dict_normalizationFactors', 'df_zscoreFeatures_training', 'df_zscoreFeatures_validation', 'df_metadata', 'umap_raw', 'umap_zscore'])

# %%
predictions_train = pd.read_excel(fn_predictionsTraining, index_col=0)
predictions_validations = pd.read_excel(fn_predictionsValidation, index_col=0)
predictions_binary = pd.concat([predictions_train, predictions_validations])
predictions_binary['id'] = predictions_binary.index
predictions_binary['id'] = predictions_binary['id'].apply(lambda x: str(x).zfill(4))
predictions_binary = predictions_binary.set_index('id')

predictions_train = pd.read_excel(fn_predictionsTraining_3g, index_col=0)
predictions_validations = pd.read_excel(fn_predictionsValidation_3g, index_col=0)
predictions_3g = pd.concat([predictions_train, predictions_validations])
predictions_3g['id'] = predictions_3g.index
predictions_3g['id'] = predictions_3g['id'].apply(lambda x: str(x).zfill(4))
predictions_3g = predictions_3g.set_index('id')

# %%
predictions_binary[500:550]

# %%
currMeta = dict_data['df_metadata']
currMeta.isnull().sum()
# Out:
# trainTest           0
# age                 0
# sex                 0
# ct_grp              0
# lre               120
# decompBL          120
# lrd               120
# lrd_tf            120
# survival          120
# survival_tf       120
# tfs               120
# tfs_tf            120
# hvpg_corrected    120
# hvpg_grp          120
# hepLrd_time       120
# hepLrd_180        120
# hepLrd_360        120
# cps               120
# cps_grp           120
# meld              120
# meld_grp          120
# etiology          120
# sodium            120
# creatinine        120
# albumin           120
# CRP               120
# INR               120
# bilirubin         120
# cntl_grp            0
# patientID           0
# dtype: int64

# %%
currMeta = currMeta.dropna()

# make variables
temp = pd.get_dummies(currMeta['meld_grp'], prefix='meldgrp')
currMeta = pd.concat([currMeta, temp], axis = 1)
temp = pd.get_dummies(currMeta['cps_grp'], prefix='cpsgrp')
currMeta = pd.concat([currMeta, temp], axis = 1)

currMeta['etio_alcLiverDisease'] = currMeta['etiology'].apply(lambda x: True if x == '1' else False)
currMeta['etio_nonAlcFattyLiver'] = currMeta['etiology'].apply(lambda x: True if x == '2' else False)
currMeta['etio_viral'] = currMeta['etiology'].apply(lambda x: True if x == '3' else False)
currMeta['etio_other'] = currMeta['etiology'].apply(lambda x: True if x == '4' else False)
currMeta['etio_unknown'] = currMeta['etiology'].apply(lambda x: True if x == '5' else False)

# add radipop predictions
currMeta = currMeta.merge(predictions_binary[['pred_bin']], how='inner', left_index=True, right_index=True)
currMeta = currMeta.merge(predictions_3g[['pred_3g']], how='inner', left_index=True, right_index=True)

currMeta

# %%
toLorenz = currMeta[['hvpg_corrected','pred_bin', 'pred_3g']]
toLorenz.to_csv(fn_forLorenz)

toLorenz

# %%
toLorenz.iloc[[116,128,141]]

# %%
timetuples = [('survival', 'survival_tf'), 
              ('lrd', 'lrd_tf'),
              ('tfs', 'tfs_tf'),
              ('lre', 'decompBL')]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
for eaTuple in timetuples:
    time = currMeta[eaTuple[0]]
    plt.hist(time, bins = 50, label=eaTuple[0])
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['survival', 'lrd', 'tfs', 'lre'])

# %%
for eaTuple in timetuples:
    time = currMeta[eaTuple[0]]
    status = currMeta[eaTuple[1]]
    kmf = KaplanMeierFitter()
    kmf.fit(durations = time, event_observed = status)
    
    fig, ax = plt.subplots(figsize=(8, 6))
    kmf.plot_survival_function()
    plt.title(eaTuple[0])

fig, ax = plt.subplots(figsize=(8, 6))
for eaTuple in timetuples:
    time = currMeta[eaTuple[0]]
    status = currMeta[eaTuple[1]]
    kmf = KaplanMeierFitter()
    kmf.fit(durations = time, event_observed = status)
    kmf.plot_survival_function()
    
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['survival', 'lrd', 'tfs', 'lre'])
plt.xlabel('Days')
plt.ylabel('Probability')
plt.savefig(fn_figure_km_big)
# Out:
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)

# %%
fig, ax = plt.subplots(figsize=(3, 3))
for eaTuple in timetuples:
    time = currMeta[eaTuple[0]]
    status = currMeta[eaTuple[1]]
    kmf = KaplanMeierFitter()
    kmf.fit(durations = time, event_observed = status)
    kmf.plot_survival_function()

plt.yticks([0, 1])
plt.xticks([0, 90, 180])

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['os', 'lrd', 'tfs', 'lre'], frameon=False)

plt.savefig(fn_figure_km)

# %%
cov_sets = {#'cps': ['age', 'sex',
#                     'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
#                     'cps_grp',
#                     'sodium', 'creatinine'],
#             'meld': ['age', 'sex',
#                      'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
#                      'meld',
#                      'albumin'],
            'radipop': ['age', 'sex',
                        'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                        'sodium', 'creatinine', 'CRP', 'bilirubin', 'albumin', 'INR', 
                        'pred_bin'],
            'radipop+cps': ['age', 'sex',
                            'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                            'cps_grp',
                            'sodium', 'creatinine',
                            'pred_bin'],
            'radipop+meld': ['age', 'sex',
                             'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                             'meld',
                             'albumin',
                             'pred_bin'],            
            'radipop_3g': ['age', 'sex',
                        'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                        'sodium', 'creatinine', 'CRP', 'bilirubin', 'albumin', 'INR', 
                        'pred_3g'],
            'radipop_3g+cps': ['age', 'sex',
                            'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                            'cps_grp',
                            'sodium', 'creatinine',
                            'pred_3g'],
            'radipop_3g+meld': ['age', 'sex',
                             'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                             'meld',
                             'albumin',
                             'pred_3g'],               
            'measured': ['age', 'sex',
                         'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                         'sodium', 'creatinine', 'CRP', 'bilirubin', 'albumin', 'INR', 
                         'hvpg_corrected'], 
            'measured+cps': ['age', 'sex',
                            'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                            'cps_grp',
                            'sodium', 'creatinine',
                            'hvpg_corrected'],
            'measured+meld': ['age', 'sex',
                             'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                             'meld',
                             'albumin',
                             'hvpg_corrected'],
            'meas_grp': ['age', 'sex',
                         'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                         'sodium', 'creatinine', 'CRP', 'bilirubin', 'albumin', 'INR', 
                         'hvpg_grp'], 
            'meas_grp+cps': ['age', 'sex',
                            'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                            'cps_grp',
                            'sodium', 'creatinine',
                            'hvpg_grp'],
            'meas_grp+meld': ['age', 'sex',
                             'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
                             'meld',
                             'albumin',
                             'hvpg_grp']
           }

# %%
allModels={}
results = pd.DataFrame()

for eaTuple in timetuples:
    for eaCovset in cov_sets:
        curr_cov = copy.deepcopy(cov_sets[eaCovset])
        curr_cov.extend([eaTuple[0], eaTuple[1]])
        temp = currMeta[curr_cov]
        cph = CoxPHFitter()
        cph.fit(temp, duration_col = eaTuple[0], event_col = eaTuple[1])
        cph.print_summary()
        modelname = eaTuple[0] + '_' + eaCovset
        allModels[modelname] = cph
        
        currResults = dict(cph.hazard_ratios_)
        currResults['AIC'] = cph.AIC_partial_
        currResults['Concordance'] = cph.concordance_index_
        curr_df = pd.DataFrame.from_dict(currResults, 
                                         orient='index',
                                         columns=[modelname])
        results = pd.merge(results, curr_df, how='outer', left_index=True, right_index=True)
# Out:
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1118.02
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.03                 1.00                 1.03
# sex                    -0.23       0.80       0.15            -0.52             0.06                 0.59                 1.07
# etio_alcLiverDisease   -0.24       0.79       0.40            -1.03             0.55                 0.36                 1.74
# etio_nonAlcFattyLiver   0.08       1.08       0.43            -0.75             0.92                 0.47                 2.50
# etio_viral             -0.17       0.85       0.41            -0.96             0.63                 0.38                 1.87
# etio_other              0.14       1.15       0.41            -0.67             0.95                 0.51                 2.58
# sodium                  0.03       1.03       0.02            -0.01             0.06                 0.99                 1.07
# creatinine              0.03       1.03       0.13            -0.23             0.29                 0.79                 1.34
# CRP                     0.00       1.00       0.04            -0.07             0.07                 0.94                 1.08
# bilirubin               0.01       1.01       0.03            -0.04             0.06                 0.96                 1.07
# albumin                 0.02       1.02       0.01            -0.01             0.05                 0.99                 1.05
# INR                     0.43       1.53       0.16             0.11             0.74                 1.12                 2.10
# pred_bin                0.13       1.14       0.18            -0.22             0.48                 0.81                 1.62
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  1.98 0.05       4.40
# sex                       0.00 -1.53 0.13       2.98
# etio_alcLiverDisease      0.00 -0.59 0.55       0.86
# etio_nonAlcFattyLiver     0.00  0.19 0.85       0.24
# etio_viral                0.00 -0.41 0.68       0.56
# etio_other                0.00  0.33 0.74       0.43
# sodium                    0.00  1.45 0.15       2.77
# creatinine                0.00  0.21 0.83       0.27
# CRP                       0.00  0.11 0.91       0.14
# bilirubin                 0.00  0.44 0.66       0.60
# albumin                   0.00  1.53 0.13       2.99
# INR                       0.00  2.66 0.01       7.00
# pred_bin                  0.00  0.75 0.45       1.14
# ---
# Concordance = 0.59
# Partial AIC = 2262.04
# log-likelihood ratio test = 25.18 on 13 df
# -log2(p) of ll-ratio test = 5.52
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1122.84
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.03
# sex                    -0.19       0.83       0.15            -0.48             0.10                 0.62                 1.11
# etio_alcLiverDisease   -0.18       0.83       0.40            -0.98             0.61                 0.38                 1.84
# etio_nonAlcFattyLiver   0.05       1.05       0.43            -0.80             0.90                 0.45                 2.45
# etio_viral             -0.14       0.87       0.41            -0.94             0.65                 0.39                 1.92
# etio_other              0.15       1.16       0.41            -0.67             0.96                 0.51                 2.60
# cps_grp                 0.10       1.11       0.11            -0.11             0.32                 0.89                 1.37
# sodium                  0.03       1.04       0.02            -0.00             0.07                 1.00                 1.07
# creatinine             -0.01       0.99       0.13            -0.27             0.25                 0.76                 1.29
# pred_bin                0.05       1.05       0.17            -0.29             0.39                 0.75                 1.48
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.08 0.04       4.74
# sex                       0.00 -1.26 0.21       2.26
# etio_alcLiverDisease      0.00 -0.45 0.65       0.62
# etio_nonAlcFattyLiver     0.00  0.12 0.91       0.14
# etio_viral                0.00 -0.35 0.73       0.46
# etio_other                0.00  0.35 0.73       0.46
# cps_grp                   0.00  0.92 0.36       1.48
# sodium                    0.00  1.90 0.06       4.12
# creatinine                0.00 -0.08 0.94       0.09
# pred_bin                  0.00  0.29 0.77       0.37
# ---
# Concordance = 0.56
# Partial AIC = 2265.68
# log-likelihood ratio test = 15.55 on 10 df
# -log2(p) of ll-ratio test = 3.14
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1121.13
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.03
# sex                    -0.26       0.77       0.15            -0.55             0.03                 0.58                 1.03
# etio_alcLiverDisease   -0.24       0.79       0.40            -1.03             0.55                 0.36                 1.74
# etio_nonAlcFattyLiver   0.10       1.10       0.43            -0.74             0.93                 0.48                 2.54
# etio_viral             -0.17       0.84       0.40            -0.96             0.62                 0.38                 1.87
# etio_other              0.11       1.12       0.41            -0.70             0.92                 0.50                 2.51
# meld                    0.03       1.04       0.01             0.01             0.06                 1.01                 1.06
# albumin                 0.03       1.03       0.01             0.00             0.05                 1.00                 1.05
# pred_bin                0.05       1.05       0.18            -0.29             0.40                 0.75                 1.48
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.06 0.04       4.66
# sex                       0.00 -1.79 0.07       3.76
# etio_alcLiverDisease      0.00 -0.59 0.56       0.84
# etio_nonAlcFattyLiver     0.00  0.23 0.82       0.29
# etio_viral                0.00 -0.42 0.68       0.57
# etio_other                0.00  0.27 0.79       0.34
# meld                      0.00  2.59 0.01       6.70
# albumin                   0.00  1.98 0.05       4.37
# pred_bin                  0.00  0.29 0.77       0.37
# ---
# Concordance = 0.58
# Partial AIC = 2260.26
# log-likelihood ratio test = 18.96 on 9 df
# -log2(p) of ll-ratio test = 5.29
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1116.64
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.03                 1.00                 1.03
# sex                    -0.21       0.81       0.15            -0.50             0.09                 0.61                 1.09
# etio_alcLiverDisease   -0.22       0.80       0.40            -1.01             0.57                 0.36                 1.76
# etio_nonAlcFattyLiver   0.11       1.12       0.43            -0.73             0.95                 0.48                 2.58
# etio_viral             -0.11       0.90       0.41            -0.90             0.69                 0.41                 2.00
# etio_other              0.26       1.29       0.42            -0.57             1.08                 0.57                 2.94
# sodium                  0.03       1.03       0.02            -0.01             0.06                 0.99                 1.07
# creatinine              0.05       1.05       0.13            -0.21             0.31                 0.81                 1.37
# CRP                     0.01       1.01       0.04            -0.06             0.08                 0.94                 1.08
# bilirubin               0.01       1.01       0.03            -0.04             0.06                 0.96                 1.06
# albumin                 0.02       1.02       0.01            -0.00             0.05                 1.00                 1.05
# INR                     0.43       1.54       0.16             0.12             0.75                 1.13                 2.12
# pred_3g                 0.19       1.21       0.10            -0.02             0.39                 0.98                 1.48
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.09 0.04       4.76
# sex                       0.00 -1.37 0.17       2.55
# etio_alcLiverDisease      0.00 -0.56 0.58       0.79
# etio_nonAlcFattyLiver     0.00  0.26 0.80       0.33
# etio_viral                0.00 -0.26 0.79       0.33
# etio_other                0.00  0.61 0.54       0.89
# sodium                    0.00  1.51 0.13       2.93
# creatinine                0.00  0.37 0.71       0.49
# CRP                       0.00  0.16 0.88       0.19
# bilirubin                 0.00  0.37 0.71       0.49
# albumin                   0.00  1.79 0.07       3.77
# INR                       0.00  2.71 0.01       7.21
# pred_3g                   0.00  1.79 0.07       3.78
# ---
# Concordance = 0.60
# Partial AIC = 2259.29
# log-likelihood ratio test = 27.94 on 13 df
# -log2(p) of ll-ratio test = 6.76
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1121.81
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.03                 1.00                 1.03
# sex                    -0.17       0.85       0.15            -0.46             0.13                 0.63                 1.13
# etio_alcLiverDisease   -0.17       0.84       0.40            -0.96             0.62                 0.38                 1.86
# etio_nonAlcFattyLiver   0.08       1.09       0.43            -0.76             0.93                 0.47                 2.54
# etio_viral             -0.09       0.92       0.41            -0.88             0.71                 0.41                 2.04
# etio_other              0.26       1.30       0.42            -0.56             1.09                 0.57                 2.97
# cps_grp                 0.07       1.08       0.11            -0.14             0.29                 0.87                 1.33
# sodium                  0.04       1.04       0.02             0.00             0.07                 1.00                 1.08
# creatinine              0.01       1.01       0.13            -0.25             0.27                 0.78                 1.31
# pred_3g                 0.15       1.16       0.10            -0.05             0.35                 0.95                 1.41
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.20 0.03       5.15
# sex                       0.00 -1.12 0.26       1.92
# etio_alcLiverDisease      0.00 -0.42 0.67       0.57
# etio_nonAlcFattyLiver     0.00  0.20 0.84       0.24
# etio_viral                0.00 -0.21 0.83       0.26
# etio_other                0.00  0.62 0.53       0.91
# cps_grp                   0.00  0.69 0.49       1.02
# sodium                    0.00  2.02 0.04       4.52
# creatinine                0.00  0.09 0.93       0.10
# pred_3g                   0.00  1.44 0.15       2.74
# ---
# Concordance = 0.56
# Partial AIC = 2263.62
# log-likelihood ratio test = 17.60 on 10 df
# -log2(p) of ll-ratio test = 4.01
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1120.04
#          time fit was run = 2023-01-17 10:21:08 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.03                 1.00                 1.03
# sex                    -0.24       0.79       0.15            -0.53             0.05                 0.59                 1.05
# etio_alcLiverDisease   -0.23       0.79       0.40            -1.02             0.56                 0.36                 1.75
# etio_nonAlcFattyLiver   0.13       1.13       0.43            -0.71             0.96                 0.49                 2.62
# etio_viral             -0.12       0.89       0.41            -0.91             0.68                 0.40                 1.97
# etio_other              0.23       1.26       0.42            -0.59             1.05                 0.55                 2.87
# meld                    0.03       1.03       0.01             0.01             0.06                 1.01                 1.06
# albumin                 0.03       1.03       0.01             0.00             0.05                 1.00                 1.06
# pred_3g                 0.15       1.16       0.10            -0.05             0.35                 0.95                 1.42
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.18 0.03       5.10
# sex                       0.00 -1.61 0.11       3.22
# etio_alcLiverDisease      0.00 -0.57 0.57       0.82
# etio_nonAlcFattyLiver     0.00  0.29 0.77       0.38
# etio_viral                0.00 -0.29 0.77       0.37
# etio_other                0.00  0.55 0.58       0.78
# meld                      0.00  2.50 0.01       6.32
# albumin                   0.00  2.26 0.02       5.41
# pred_3g                   0.00  1.49 0.14       2.86
# ---
# Concordance = 0.58
# Partial AIC = 2258.09
# log-likelihood ratio test = 21.14 on 9 df
# -log2(p) of ll-ratio test = 6.38
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1118.05
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01            -0.00             0.02                 1.00                 1.02
# sex                    -0.23       0.80       0.15            -0.52             0.07                 0.59                 1.07
# etio_alcLiverDisease   -0.27       0.76       0.41            -1.07             0.53                 0.34                 1.70
# etio_nonAlcFattyLiver   0.06       1.06       0.43            -0.78             0.90                 0.46                 2.45
# etio_viral             -0.18       0.83       0.41            -0.98             0.61                 0.38                 1.84
# etio_other              0.12       1.13       0.41            -0.69             0.93                 0.50                 2.53
# sodium                  0.03       1.03       0.02            -0.01             0.06                 0.99                 1.07
# creatinine              0.02       1.02       0.13            -0.24             0.29                 0.79                 1.33
# CRP                     0.01       1.01       0.04            -0.06             0.08                 0.94                 1.08
# bilirubin               0.01       1.01       0.03            -0.04             0.06                 0.96                 1.07
# albumin                 0.02       1.02       0.01            -0.01             0.05                 0.99                 1.05
# INR                     0.41       1.51       0.16             0.10             0.73                 1.10                 2.07
# hvpg_corrected          0.01       1.01       0.01            -0.01             0.03                 0.99                 1.03
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  1.87 0.06       4.03
# sex                       0.00 -1.52 0.13       2.95
# etio_alcLiverDisease      0.00 -0.66 0.51       0.97
# etio_nonAlcFattyLiver     0.00  0.13 0.90       0.16
# etio_viral                0.00 -0.46 0.65       0.62
# etio_other                0.00  0.29 0.77       0.38
# sodium                    0.00  1.48 0.14       2.84
# creatinine                0.00  0.18 0.86       0.22
# CRP                       0.00  0.19 0.85       0.24
# bilirubin                 0.00  0.44 0.66       0.60
# albumin                   0.00  1.53 0.13       3.00
# INR                       0.00  2.58 0.01       6.66
# hvpg_corrected            0.00  0.72 0.47       1.09
# ---
# Concordance = 0.59
# Partial AIC = 2262.09
# log-likelihood ratio test = 25.13 on 13 df
# -log2(p) of ll-ratio test = 5.49
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1122.77
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.02
# sex                    -0.18       0.83       0.15            -0.47             0.11                 0.62                 1.11
# etio_alcLiverDisease   -0.21       0.81       0.41            -1.01             0.59                 0.37                 1.81
# etio_nonAlcFattyLiver   0.04       1.04       0.43            -0.81             0.89                 0.45                 2.43
# etio_viral             -0.15       0.86       0.41            -0.94             0.65                 0.39                 1.91
# etio_other              0.15       1.16       0.41            -0.66             0.96                 0.52                 2.60
# cps_grp                 0.09       1.09       0.11            -0.13             0.31                 0.88                 1.37
# sodium                  0.04       1.04       0.02            -0.00             0.07                 1.00                 1.07
# creatinine             -0.01       0.99       0.13            -0.27             0.25                 0.76                 1.28
# hvpg_corrected          0.00       1.00       0.01            -0.02             0.03                 0.98                 1.03
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.02 0.04       4.52
# sex                       0.00 -1.24 0.21       2.23
# etio_alcLiverDisease      0.00 -0.50 0.61       0.70
# etio_nonAlcFattyLiver     0.00  0.09 0.93       0.11
# etio_viral                0.00 -0.37 0.71       0.49
# etio_other                0.00  0.36 0.72       0.47
# cps_grp                   0.00  0.79 0.43       1.22
# sodium                    0.00  1.93 0.05       4.21
# creatinine                0.00 -0.08 0.94       0.09
# hvpg_corrected            0.00  0.47 0.64       0.65
# ---
# Concordance = 0.56
# Partial AIC = 2265.54
# log-likelihood ratio test = 15.69 on 10 df
# -log2(p) of ll-ratio test = 3.20
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1121.17
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.03
# sex                    -0.26       0.77       0.15            -0.55             0.02                 0.57                 1.03
# etio_alcLiverDisease   -0.24       0.79       0.41            -1.04             0.56                 0.35                 1.75
# etio_nonAlcFattyLiver   0.09       1.10       0.43            -0.74             0.93                 0.48                 2.54
# etio_viral             -0.17       0.84       0.40            -0.97             0.62                 0.38                 1.86
# etio_other              0.10       1.11       0.41            -0.71             0.91                 0.49                 2.48
# meld                    0.03       1.04       0.01             0.01             0.06                 1.01                 1.06
# albumin                 0.03       1.03       0.01            -0.00             0.05                 1.00                 1.05
# hvpg_corrected          0.00       1.00       0.01            -0.02             0.02                 0.98                 1.02
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.02 0.04       4.53
# sex                       0.00 -1.79 0.07       3.77
# etio_alcLiverDisease      0.00 -0.58 0.56       0.83
# etio_nonAlcFattyLiver     0.00  0.22 0.83       0.27
# etio_viral                0.00 -0.43 0.67       0.58
# etio_other                0.00  0.25 0.81       0.31
# meld                      0.00  2.51 0.01       6.39
# albumin                   0.00  1.94 0.05       4.25
# hvpg_corrected            0.00  0.13 0.90       0.15
# ---
# Concordance = 0.58
# Partial AIC = 2260.33
# log-likelihood ratio test = 18.89 on 9 df
# -log2(p) of ll-ratio test = 5.26
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1116.76
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01            -0.00             0.02                 1.00                 1.03
# sex                    -0.21       0.81       0.15            -0.51             0.08                 0.60                 1.09
# etio_alcLiverDisease   -0.31       0.73       0.41            -1.11             0.49                 0.33                 1.63
# etio_nonAlcFattyLiver   0.04       1.04       0.43            -0.80             0.87                 0.45                 2.40
# etio_viral             -0.18       0.84       0.41            -0.97             0.62                 0.38                 1.86
# etio_other              0.18       1.20       0.41            -0.63             0.99                 0.53                 2.69
# sodium                  0.03       1.03       0.02            -0.01             0.07                 0.99                 1.07
# creatinine              0.04       1.04       0.13            -0.23             0.30                 0.80                 1.35
# CRP                     0.01       1.01       0.04            -0.06             0.08                 0.94                 1.09
# bilirubin               0.01       1.01       0.03            -0.04             0.06                 0.96                 1.07
# albumin                 0.02       1.03       0.01            -0.00             0.05                 1.00                 1.05
# INR                     0.41       1.50       0.16             0.09             0.73                 1.09                 2.07
# hvpg_grp                0.13       1.13       0.07            -0.02             0.27                 0.98                 1.31
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  1.95 0.05       4.30
# sex                       0.00 -1.41 0.16       2.66
# etio_alcLiverDisease      0.00 -0.76 0.45       1.16
# etio_nonAlcFattyLiver     0.00  0.09 0.93       0.10
# etio_viral                0.00 -0.43 0.66       0.59
# etio_other                0.00  0.43 0.66       0.59
# sodium                    0.00  1.57 0.12       3.10
# creatinine                0.00  0.27 0.79       0.34
# CRP                       0.00  0.38 0.70       0.51
# bilirubin                 0.00  0.40 0.69       0.54
# albumin                   0.00  1.86 0.06       3.99
# INR                       0.00  2.50 0.01       6.32
# hvpg_grp                  0.00  1.75 0.08       3.64
# ---
# Concordance = 0.60
# Partial AIC = 2259.52
# log-likelihood ratio test = 27.70 on 13 df
# -log2(p) of ll-ratio test = 6.65
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1121.65
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.03
# sex                    -0.16       0.85       0.15            -0.45             0.13                 0.64                 1.14
# etio_alcLiverDisease   -0.24       0.78       0.41            -1.04             0.55                 0.35                 1.74
# etio_nonAlcFattyLiver   0.04       1.04       0.43            -0.81             0.88                 0.45                 2.42
# etio_viral             -0.14       0.87       0.41            -0.93             0.66                 0.39                 1.93
# etio_other              0.21       1.24       0.41            -0.60             1.03                 0.55                 2.79
# cps_grp                 0.06       1.07       0.11            -0.15             0.28                 0.86                 1.32
# sodium                  0.04       1.04       0.02             0.00             0.07                 1.00                 1.08
# creatinine              0.00       1.00       0.13            -0.26             0.26                 0.77                 1.30
# hvpg_grp                0.11       1.11       0.07            -0.03             0.24                 0.97                 1.27
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.08 0.04       4.73
# sex                       0.00 -1.09 0.28       1.86
# etio_alcLiverDisease      0.00 -0.60 0.55       0.86
# etio_nonAlcFattyLiver     0.00  0.09 0.93       0.10
# etio_viral                0.00 -0.34 0.74       0.44
# etio_other                0.00  0.51 0.61       0.72
# cps_grp                   0.00  0.58 0.56       0.82
# sodium                    0.00  2.03 0.04       4.57
# creatinine                0.00  0.00 1.00       0.00
# hvpg_grp                  0.00  1.56 0.12       3.06
# ---
# Concordance = 0.57
# Partial AIC = 2263.31
# log-likelihood ratio test = 17.92 on 10 df
# -log2(p) of ll-ratio test = 4.15
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 209 right-censored observations>
#              duration col = 'survival'
#                 event col = 'survival_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 233
#    partial log-likelihood = -1120.30
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.03
# sex                    -0.24       0.79       0.15            -0.53             0.05                 0.59                 1.05
# etio_alcLiverDisease   -0.30       0.74       0.41            -1.09             0.50                 0.34                 1.65
# etio_nonAlcFattyLiver   0.07       1.07       0.43            -0.77             0.90                 0.46                 2.47
# etio_viral             -0.18       0.84       0.40            -0.97             0.62                 0.38                 1.85
# etio_other              0.16       1.17       0.41            -0.65             0.97                 0.52                 2.64
# meld                    0.03       1.03       0.01             0.00             0.06                 1.00                 1.06
# albumin                 0.03       1.03       0.01             0.00             0.05                 1.00                 1.06
# hvpg_grp                0.09       1.10       0.07            -0.05             0.23                 0.95                 1.26
#
#                         cmp to     z    p   -log2(p)
# covariate
# age                       0.00  2.03 0.04       4.57
# sex                       0.00 -1.62 0.10       3.25
# etio_alcLiverDisease      0.00 -0.73 0.47       1.10
# etio_nonAlcFattyLiver     0.00  0.16 0.87       0.20
# etio_viral                0.00 -0.44 0.66       0.60
# etio_other                0.00  0.39 0.70       0.52
# meld                      0.00  2.26 0.02       5.39
# albumin                   0.00  2.21 0.03       5.19
# hvpg_grp                  0.00  1.31 0.19       2.40
# ---
# Concordance = 0.58
# Partial AIC = 2258.61
# log-likelihood ratio test = 20.61 on 9 df
# -log2(p) of ll-ratio test = 6.11
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 290 right-censored observations>
#              duration col = 'lrd'
#                 event col = 'lrd_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 152
#    partial log-likelihood = -805.41
#          time fit was run = 2023-01-17 10:21:09 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
# sex                    -0.04       0.96       0.19            -0.41             0.33                 0.66                 1.39
# etio_alcLiverDisease    0.12       1.13       0.48            -0.81             1.05                 0.44                 2.87
# etio_nonAlcFattyLiver  -0.05       0.95       0.52            -1.07             0.98                 0.34                 2.65
# etio_viral              0.03       1.03       0.49            -0.93             1.00                 0.39                 2.70
# etio_other              0.27       1.31       0.50            -0.70             1.24                 0.49                 3.45
# sodium                 -0.02       0.98       0.02            -0.05             0.02                 0.95                 1.02
# creatinine             -0.02       0.98       0.17            -0.35             0.30                 0.71                 1.35
# CRP                     0.07       1.07       0.03             0.00             0.13                 1.00                 1.14
# bilirubin               0.03       1.03       0.03            -0.03             0.08                 0.97                 1.09
# albumin                -0.04       0.96       0.02            -0.07            -0.00                 0.93                 1.00
# INR                     0.10       1.11       0.24            -0.36             0.57                 0.70                 1.77
# pred_bin                0.35       1.41       0.24            -0.12             0.82                 0.88                 2.26
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  4.77 <0.005      19.06
# sex                       0.00 -0.22   0.82       0.28
# etio_alcLiverDisease      0.00  0.25   0.80       0.32
# etio_nonAlcFattyLiver     0.00 -0.09   0.93       0.11
# etio_viral                0.00  0.07   0.95       0.08
# etio_other                0.00  0.54   0.59       0.76
# sodium                    0.00 -0.84   0.40       1.31
# creatinine                0.00 -0.13   0.90       0.16
# CRP                       0.00  2.02   0.04       4.54
# bilirubin                 0.00  0.88   0.38       1.39
# albumin                   0.00 -2.25   0.02       5.34
# INR                       0.00  0.44   0.66       0.60
# pred_bin                  0.00  1.44   0.15       2.74
# ---
# Concordance = 0.65
# Partial AIC = 1636.83
# log-likelihood ratio test = 45.86 on 13 df
# -log2(p) of ll-ratio test = 16.02
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 290 right-censored observations>
#              duration col = 'lrd'
#                 event col = 'lrd_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 152
#    partial log-likelihood = -808.36
#          time fit was run = 2023-01-17 10:21:10 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.04       1.04       0.01             0.02             0.05                 1.02                 1.06
# sex                     0.01       1.01       0.19            -0.36             0.38                 0.70                 1.46
# etio_alcLiverDisease   -0.01       0.99       0.48            -0.95             0.92                 0.39                 2.51
# etio_nonAlcFattyLiver  -0.21       0.81       0.53            -1.24             0.82                 0.29                 2.28
# etio_viral             -0.06       0.94       0.49            -1.02             0.90                 0.36                 2.45
# etio_other              0.21       1.23       0.49            -0.76             1.18                 0.47                 3.25
# cps_grp                 0.44       1.56       0.13             0.19             0.70                 1.21                 2.01
# sodium                 -0.02       0.98       0.02            -0.05             0.02                 0.95                 1.02
# creatinine             -0.02       0.98       0.17            -0.35             0.31                 0.71                 1.36
# pred_bin                0.37       1.45       0.24            -0.09             0.84                 0.91                 2.31
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  4.55 <0.005      17.48
# sex                       0.00  0.05   0.96       0.06
# etio_alcLiverDisease      0.00 -0.03   0.97       0.04
# etio_nonAlcFattyLiver     0.00 -0.39   0.69       0.53
# etio_viral                0.00 -0.13   0.90       0.16
# etio_other                0.00  0.42   0.67       0.57
# cps_grp                   0.00  3.39 <0.005      10.48
# sodium                    0.00 -0.86   0.39       1.36
# creatinine                0.00 -0.11   0.91       0.13
# pred_bin                  0.00  1.56   0.12       3.08
# ---
# Concordance = 0.65
# Partial AIC = 1636.73
# log-likelihood ratio test = 39.96 on 10 df
# -log2(p) of ll-ratio test = 15.83
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 290 right-censored observations>
#              duration col = 'lrd'
#                 event col = 'lrd_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 152
#    partial log-likelihood = -807.59
#          time fit was run = 2023-01-17 10:21:10 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.04       1.04       0.01             0.02             0.05                 1.02                 1.06
# sex                    -0.02       0.98       0.18            -0.38             0.35                 0.68                 1.41
# etio_alcLiverDisease    0.12       1.12       0.47            -0.81             1.05                 0.44                 2.85
# etio_nonAlcFattyLiver  -0.03       0.97       0.52            -1.05             0.99                 0.35                 2.70
# etio_viral             -0.01       0.99       0.49            -0.97             0.95                 0.38                 2.60
# etio_other              0.29       1.34       0.50            -0.68             1.26                 0.51                 3.53
# meld                    0.03       1.03       0.02            -0.00             0.06                 1.00                 1.06
# albumin                -0.04       0.96       0.02            -0.07            -0.01                 0.93                 0.99
# pred_bin                0.32       1.38       0.24            -0.15             0.79                 0.86                 2.20
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  4.58 <0.005      17.73
# sex                       0.00 -0.09   0.93       0.11
# etio_alcLiverDisease      0.00  0.25   0.80       0.31
# etio_nonAlcFattyLiver     0.00 -0.05   0.96       0.06
# etio_viral                0.00 -0.01   0.99       0.01
# etio_other                0.00  0.58   0.56       0.84
# meld                      0.00  1.64   0.10       3.31
# albumin                   0.00 -2.80   0.01       7.60
# pred_bin                  0.00  1.34   0.18       2.47
# ---
# Concordance = 0.65
# Partial AIC = 1633.18
# log-likelihood ratio test = 41.51 on 9 df
# -log2(p) of ll-ratio test = 17.92
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 290 right-censored observations>
#              duration col = 'lrd'
#                 event col = 'lrd_tf'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 152
#    partial log-likelihood = -805.89
#          time fit was run = 2023-01-17 10:21:10 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
# sex                    -0.05       0.95       0.19            -0.42             0.33                 0.66                 1.38
# etio_alcLiverDisease    0.14       1.16       0.47            -0.79             1.08                 0.46                 2.93
# etio_nonAlcFattyLiver  -0.04       0.96       0.52            -1.07             0.98                 0.34                 2.67
# etio_viral              0.05       1.06       0.49            -0.91             1.02                 0.40                 2.77
# etio_other              0.30       1.35       0.50            -0.68             1.28                 0.51                 3.61
# sodium                 -0.02       0.98       0.02            -0.05             0.02                 0.95                 1.02
# creatinine             -0.02       0.98       0.16            -0.34             0.30                 0.71                 1.36
# ...
# covariate
# age                       0.00  0.12   0.90       0.15
# sex                       0.00 -1.68   0.09       3.41
# etio_alcLiverDisease      0.00 -0.01   0.99       0.01
# etio_nonAlcFattyLiver     0.00  0.82   0.41       1.28
# etio_viral                0.00 -1.66   0.10       3.38
# etio_other                0.00  0.25   0.80       0.32
# sodium                    0.00 -3.91 <0.005      13.39
# creatinine                0.00  4.68 <0.005      18.38
# CRP                       0.00  1.24   0.22       2.22
# bilirubin                 0.00 -0.67   0.50       0.99
# albumin                   0.00 -4.88 <0.005      19.86
# INR                       0.00  1.60   0.11       3.19
# hvpg_corrected            0.00  5.30 <0.005      23.07
# ---
# Concordance = 0.76
# Partial AIC = 2732.68
# log-likelihood ratio test = 208.73 on 13 df
# -log2(p) of ll-ratio test = 121.78
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 170 right-censored observations>
#              duration col = 'lre'
#                 event col = 'decompBL'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 272
#    partial log-likelihood = -1323.79
#          time fit was run = 2023-01-17 10:21:14 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01            -0.00             0.02                 1.00                 1.02
# sex                    -0.17       0.84       0.14            -0.44             0.10                 0.64                 1.11
# etio_alcLiverDisease   -0.17       0.84       0.41            -0.97             0.63                 0.38                 1.87
# etio_nonAlcFattyLiver   0.09       1.10       0.43            -0.76             0.94                 0.47                 2.57
# etio_viral             -0.74       0.48       0.43            -1.58             0.10                 0.21                 1.10
# etio_other             -0.03       0.97       0.41            -0.84             0.79                 0.43                 2.20
# cps_grp                 1.04       2.82       0.10             0.83             1.24                 2.30                 3.44
# sodium                 -0.03       0.97       0.01            -0.06            -0.01                 0.94                 0.99
# creatinine              0.55       1.73       0.11             0.34             0.75                 1.40                 2.13
# hvpg_corrected          0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  1.58   0.12       3.12
# sex                       0.00 -1.22   0.22       2.18
# etio_alcLiverDisease      0.00 -0.42   0.67       0.57
# etio_nonAlcFattyLiver     0.00  0.21   0.83       0.27
# etio_viral                0.00 -1.74   0.08       3.60
# etio_other                0.00 -0.06   0.95       0.07
# cps_grp                   0.00 10.11 <0.005      77.39
# sodium                    0.00 -2.45   0.01       6.15
# creatinine                0.00  5.13 <0.005      21.73
# hvpg_corrected            0.00  4.40 <0.005      16.49
# ---
# Concordance = 0.79
# Partial AIC = 2667.59
# log-likelihood ratio test = 267.82 on 10 df
# -log2(p) of ll-ratio test = 169.47
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 170 right-censored observations>
#              duration col = 'lre'
#                 event col = 'decompBL'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 272
#    partial log-likelihood = -1359.65
#          time fit was run = 2023-01-17 10:21:14 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.00       1.00       0.01            -0.01             0.02                 0.99                 1.02
# sex                    -0.16       0.85       0.13            -0.43             0.10                 0.65                 1.10
# etio_alcLiverDisease   -0.09       0.92       0.40            -0.87             0.70                 0.42                 2.01
# etio_nonAlcFattyLiver   0.21       1.24       0.42            -0.62             1.04                 0.54                 2.84
# etio_viral             -0.79       0.45       0.42            -1.62             0.03                 0.20                 1.03
# etio_other              0.01       1.01       0.41            -0.80             0.81                 0.45                 2.25
# meld                    0.05       1.05       0.01             0.03             0.07                 1.03                 1.07
# albumin                -0.06       0.94       0.01            -0.09            -0.04                 0.92                 0.96
# hvpg_corrected          0.04       1.04       0.01             0.02             0.06                 1.02                 1.06
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  0.84   0.40       1.33
# sex                       0.00 -1.22   0.22       2.17
# etio_alcLiverDisease      0.00 -0.21   0.83       0.27
# etio_nonAlcFattyLiver     0.00  0.50   0.62       0.69
# etio_viral                0.00 -1.89   0.06       4.10
# etio_other                0.00  0.02   0.99       0.02
# meld                      0.00  4.70 <0.005      18.55
# albumin                   0.00 -5.47 <0.005      24.42
# hvpg_corrected            0.00  4.51 <0.005      17.26
# ---
# Concordance = 0.75
# Partial AIC = 2737.29
# log-likelihood ratio test = 196.11 on 9 df
# -log2(p) of ll-ratio test = 121.80
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 170 right-censored observations>
#              duration col = 'lre'
#                 event col = 'decompBL'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 272
#    partial log-likelihood = -1353.41
#          time fit was run = 2023-01-17 10:21:14 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.00       1.00       0.01            -0.01             0.02                 0.99                 1.02
# sex                    -0.19       0.83       0.14            -0.46             0.08                 0.63                 1.09
# etio_alcLiverDisease    0.12       1.13       0.40            -0.67             0.91                 0.51                 2.48
# etio_nonAlcFattyLiver   0.39       1.48       0.43            -0.46             1.24                 0.63                 3.44
# etio_viral             -0.58       0.56       0.42            -1.41             0.25                 0.24                 1.29
# etio_other              0.25       1.28       0.42            -0.57             1.06                 0.57                 2.89
# sodium                 -0.06       0.94       0.01            -0.09            -0.03                 0.91                 0.97
# creatinine              0.47       1.60       0.10             0.27             0.68                 1.31                 1.97
# CRP                     0.03       1.03       0.02            -0.02             0.07                 0.98                 1.07
# bilirubin              -0.01       0.99       0.02            -0.05             0.02                 0.95                 1.02
# albumin                -0.06       0.94       0.01            -0.09            -0.04                 0.92                 0.96
# INR                     0.22       1.25       0.15            -0.07             0.52                 0.93                 1.68
# hvpg_grp                0.39       1.47       0.08             0.23             0.55                 1.26                 1.73
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  0.61   0.54       0.88
# sex                       0.00 -1.36   0.17       2.52
# etio_alcLiverDisease      0.00  0.30   0.76       0.39
# etio_nonAlcFattyLiver     0.00  0.90   0.37       1.45
# etio_viral                0.00 -1.36   0.17       2.52
# etio_other                0.00  0.60   0.55       0.86
# sodium                    0.00 -4.31 <0.005      15.89
# creatinine                0.00  4.53 <0.005      17.35
# CRP                       0.00  1.12   0.26       1.92
# bilirubin                 0.00 -0.74   0.46       1.12
# albumin                   0.00 -5.13 <0.005      21.71
# INR                       0.00  1.46   0.14       2.80
# hvpg_grp                  0.00  4.76 <0.005      18.99
# ---
# Concordance = 0.75
# Partial AIC = 2732.81
# log-likelihood ratio test = 208.59 on 13 df
# -log2(p) of ll-ratio test = 121.68
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 170 right-censored observations>
#              duration col = 'lre'
#                 event col = 'decompBL'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 272
#    partial log-likelihood = -1324.79
#          time fit was run = 2023-01-17 10:21:14 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01             0.00             0.02                 1.00                 1.02
# sex                    -0.14       0.87       0.14            -0.41             0.14                 0.66                 1.15
# etio_alcLiverDisease   -0.07       0.93       0.41            -0.87             0.73                 0.42                 2.07
# etio_nonAlcFattyLiver   0.13       1.14       0.44            -0.73             0.98                 0.48                 2.67
# etio_viral             -0.62       0.54       0.43            -1.46             0.23                 0.23                 1.25
# etio_other              0.08       1.08       0.42            -0.74             0.90                 0.48                 2.45
# cps_grp                 1.03       2.80       0.10             0.83             1.23                 2.29                 3.43
# sodium                 -0.04       0.96       0.01            -0.06            -0.01                 0.94                 0.99
# creatinine              0.54       1.71       0.11             0.32             0.75                 1.38                 2.12
# hvpg_grp                0.30       1.35       0.08             0.15             0.46                 1.16                 1.58
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  2.06   0.04       4.68
# sex                       0.00 -0.97   0.33       1.59
# etio_alcLiverDisease      0.00 -0.17   0.86       0.21
# etio_nonAlcFattyLiver     0.00  0.29   0.77       0.38
# etio_viral                0.00 -1.43   0.15       2.72
# etio_other                0.00  0.19   0.85       0.23
# cps_grp                   0.00 10.02 <0.005      76.15
# sodium                    0.00 -2.76   0.01       7.44
# creatinine                0.00  4.92 <0.005      20.13
# hvpg_grp                  0.00  3.80 <0.005      12.75
# ---
# Concordance = 0.79
# Partial AIC = 2669.59
# log-likelihood ratio test = 265.82 on 10 df
# -log2(p) of ll-ratio test = 168.07
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# <lifelines.CoxPHFitter: fitted with 442 total observations, 170 right-censored observations>
#              duration col = 'lre'
#                 event col = 'decompBL'
#       baseline estimation = breslow
#    number of observations = 442
# number of events observed = 272
#    partial log-likelihood = -1360.35
#          time fit was run = 2023-01-17 10:21:15 UTC
#
# ---
#                         coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                     0.01       1.01       0.01            -0.00             0.02                 1.00                 1.02
# sex                    -0.13       0.88       0.14            -0.39             0.14                 0.68                 1.15
# etio_alcLiverDisease    0.03       1.03       0.40            -0.75             0.80                 0.47                 2.23
# etio_nonAlcFattyLiver   0.24       1.27       0.42            -0.59             1.07                 0.55                 2.92
# etio_viral             -0.69       0.50       0.42            -1.51             0.13                 0.22                 1.14
# etio_other              0.12       1.13       0.41            -0.69             0.94                 0.50                 2.55
# meld                    0.05       1.05       0.01             0.03             0.07                 1.03                 1.07
# albumin                -0.07       0.94       0.01            -0.09            -0.04                 0.91                 0.96
# hvpg_grp                0.32       1.37       0.08             0.16             0.47                 1.17                 1.60
#
#                         cmp to     z      p   -log2(p)
# covariate
# age                       0.00  1.26   0.21       2.26
# sex                       0.00 -0.93   0.35       1.50
# etio_alcLiverDisease      0.00  0.07   0.95       0.08
# etio_nonAlcFattyLiver     0.00  0.57   0.57       0.81
# etio_viral                0.00 -1.65   0.10       3.33
# etio_other                0.00  0.30   0.77       0.39
# meld                      0.00  4.75 <0.005      18.91
# albumin                   0.00 -5.68 <0.005      26.11
# hvpg_grp                  0.00  3.94 <0.005      13.58
# ---
# Concordance = 0.74
# Partial AIC = 2738.69
# log-likelihood ratio test = 194.72 on 9 df
# -log2(p) of ll-ratio test = 120.83

# %%
# reorder rows
orderIndex = ['age', 'sex',
              'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
              'sodium', 'creatinine', 'CRP', 'INR', 'bilirubin', 'albumin',
              'cps_grp', 'meld',
              'pred_bin', 'hvpg_corrected', 'hvpg_grp',
              'AIC', 'Concordance'
             ]
results = results.reindex(orderIndex)
results
# Out:
#                        survival_radipop  survival_radipop+cps  \
# age                            1.012693              1.012897
# sex                            0.795326              0.829939
# etio_alcLiverDisease           0.786676              0.832219
# etio_nonAlcFattyLiver          1.084623              1.051822
# etio_viral                     0.845972              0.867707
# etio_other                     1.146224              1.156681
# sodium                         1.027234              1.035584
# creatinine                     1.029051              0.989735
# CRP                            1.004073                   NaN
# INR                            1.533860                   NaN
# bilirubin                      1.011821                   NaN
# albumin                        1.020380                   NaN
# cps_grp                             NaN              1.106162
# meld                                NaN                   NaN
# pred_bin                       1.142720              1.051452
# hvpg_corrected                      NaN                   NaN
# hvpg_grp                            NaN                   NaN
# AIC                         2262.043022           2265.675882
# Concordance                    0.592386              0.560206
#
#                        survival_radipop+meld  survival_radipop_3g  \
# age                                 1.012854             1.013309
# sex                                 0.768417             0.813743
# etio_alcLiverDisease                0.789249             0.799558
# etio_nonAlcFattyLiver               1.102310             1.117009
# etio_viral                          0.844325             0.899611
# etio_other                          1.117229             1.292190
# sodium                                   NaN             1.028315
# creatinine                               NaN             1.051057
# CRP                                      NaN             1.005613
# INR                                      NaN             1.544529
# bilirubin                                NaN             1.009896
# albumin                             1.026266             1.023677
# cps_grp                                  NaN                  NaN
# meld                                1.035080                  NaN
# pred_bin                            1.052226                  NaN
# hvpg_corrected                           NaN                  NaN
# hvpg_grp                                 NaN                  NaN
# AIC                              2260.262712          2259.287873
# Concordance                         0.578693             0.598229
#
#                        survival_radipop_3g+cps  survival_radipop_3g+meld  \
# age                                   1.013570                  1.013607
# sex                                   0.846888                  0.787515
# etio_alcLiverDisease                  0.843046                  0.794795
# etio_nonAlcFattyLiver                 1.088427                  1.133781
# etio_viral                            0.918468                  0.889867
# etio_other                            1.300219                  1.260507
# sodium                                1.037772                       NaN
# creatinine                            1.011705                       NaN
# CRP                                        NaN                       NaN
# INR                                        NaN                       NaN
# bilirubin                                  NaN                       NaN
# albumin                                    NaN                  1.029905
# cps_grp                               1.077221                       NaN
# meld                                       NaN                  1.033940
# pred_bin                                   NaN                       NaN
# hvpg_corrected                             NaN                       NaN
# hvpg_grp                                   NaN                       NaN
# AIC                                2263.619827               2258.085046
# Concordance                           0.559339                  0.582139
#
#                        survival_measured  survival_measured+cps  \
# age                             1.011964               1.012481
# sex                             0.796398               0.831668
# etio_alcLiverDisease            0.764801               0.814285
# etio_nonAlcFattyLiver           1.057906               1.040912
# etio_viral                      0.831145               0.860763
# etio_other                      1.128972               1.158982
# sodium                          1.027869               1.036109
# creatinine                      1.024197               0.989921
# CRP                             1.007184                    NaN
# INR                             1.512755                    NaN
# bilirubin                       1.011880                    NaN
# albumin                         1.020938                    NaN
# cps_grp                              NaN               1.094208
# meld                                 NaN                    NaN
# pred_bin                             NaN                    NaN
# hvpg_corrected                  1.007651               1.004867
# hvpg_grp                             NaN                    NaN
# AIC                          2262.094723            2265.538416
# Concordance                     0.594669               0.561211
#
#                        survival_measured+meld  survival_meas_grp  ...  \
# age                                  1.012627           1.012548  ...
# sex                                  0.767680           0.809022  ...
# etio_alcLiverDisease                 0.788960           0.733833  ...
# etio_nonAlcFattyLiver                1.097761           1.037793  ...
# etio_viral                           0.840570           0.838414  ...
# etio_other                           1.107047           1.196508  ...
# sodium                                    NaN           1.029402  ...
# creatinine                                NaN           1.036415  ...
# CRP                                       NaN           1.013882  ...
# INR                                       NaN           1.502528  ...
# bilirubin                                 NaN           1.010945  ...
# albumin                              1.025657           1.025127  ...
# cps_grp                                   NaN                NaN  ...
# meld                                 1.035008                NaN  ...
# pred_bin                                  NaN                NaN  ...
# hvpg_corrected                       1.001324                NaN  ...
# hvpg_grp                                  NaN           1.133754  ...
# AIC                               2260.331086        2259.520273  ...
# Concordance                          0.579560           0.601378  ...
#
#                        lre_radipop+meld  lre_radipop_3g  lre_radipop_3g+cps  \
# age                            1.009322        1.004527            1.014475
# sex                            0.837727        0.795396            0.841881
# etio_alcLiverDisease           1.109906        1.350614            1.095595
# etio_nonAlcFattyLiver          1.377381        1.802720            1.271401
# etio_viral                     0.496023        0.598386            0.584388
# etio_other                     1.078746        1.425428            1.234550
# sodium                              NaN        0.936946            0.961513
# creatinine                          NaN        1.644004            1.756822
# CRP                                 NaN        1.006900                 NaN
# INR                                 NaN        1.300488                 NaN
# bilirubin                           NaN        0.988371                 NaN
# albumin                        0.934115        0.930868                 NaN
# cps_grp                             NaN             NaN            2.943714
# meld                           1.055329             NaN                 NaN
# pred_bin                       2.088480             NaN                 NaN
# hvpg_corrected                      NaN             NaN                 NaN
# hvpg_grp                            NaN             NaN                 NaN
# AIC                         2740.672028     2739.040168         2669.552523
# Concordance                    0.742384        0.749177            0.784122
#
#                        lre_radipop_3g+meld  lre_measured  lre_measured+cps  \
# age                               1.008860      1.000728          1.009560
# sex                               0.847108      0.794035          0.844391
# etio_alcLiverDisease              1.149461      0.996759          0.842443
# etio_nonAlcFattyLiver             1.382746      1.423962          1.097463
# etio_viral                        0.520225      0.495510          0.476554
# etio_other                        1.224166      1.109078          0.974911
# sodium                                 NaN      0.944419          0.966077
# creatinine                             NaN      1.598611          1.726577
# CRP                                    NaN      1.029438               NaN
# INR                                    NaN      1.273778               NaN
# bilirubin                              NaN      0.988034               NaN
# albumin                           0.932756      0.940719               NaN
# cps_grp                                NaN           NaN          2.816927
# meld                              1.057100           NaN               NaN
# pred_bin                               NaN           NaN               NaN
# hvpg_corrected                         NaN      1.048537          1.039760
# hvpg_grp                               NaN           NaN               NaN
# AIC                            2740.246296   2732.678241       2667.586452
# Concordance                       0.738016      0.760480          0.789284
#
#                        lre_measured+meld  lre_meas_grp  lre_meas_grp+cps  \
# age                             1.004938      1.003622          1.012520
# sex                             0.848339      0.828679          0.873392
# etio_alcLiverDisease            0.918138      1.128139          0.932741
# etio_nonAlcFattyLiver           1.235800      1.477035          1.137082
# etio_viral                      0.452026      0.561797          0.540390
# etio_other                      1.006660      1.281783          1.080687
# sodium                               NaN      0.940114          0.962783
# creatinine                           NaN      1.602568          1.713647
# CRP                                  NaN      1.026212               NaN
# INR                                  NaN      1.247708               NaN
# bilirubin                            NaN      0.987220               NaN
# albumin                         0.937401      0.938050               NaN
# cps_grp                              NaN           NaN          2.800893
# meld                            1.050151           NaN               NaN
# pred_bin                             NaN           NaN               NaN
# hvpg_corrected                  1.040063           NaN               NaN
# hvpg_grp                             NaN      1.473094          1.354188
# AIC                          2737.294366   2732.814095       2669.585910
# Concordance                     0.747660      0.752425          0.787923
#
#                        lre_meas_grp+meld
# age                             1.007364
# sex                             0.881679
# etio_alcLiverDisease            1.026570
# etio_nonAlcFattyLiver           1.271759
# etio_viral                      0.500548
# etio_other                      1.131620
# sodium                               NaN
# creatinine                           NaN
# CRP                                  NaN
# INR                                  NaN
# bilirubin                            NaN
# albumin                         0.935125
# cps_grp                              NaN
# meld                            1.050510
# pred_bin                             NaN
# hvpg_corrected                       NaN
# hvpg_grp                        1.370807
# AIC                          2738.690944
# Concordance                     0.741051
#
# [19 rows x 48 columns]

# %%
results.iloc[:,0:6]
# Out:
#                        survival_radipop  survival_radipop+cps  \
# age                            1.012693              1.012897
# sex                            0.795326              0.829939
# etio_alcLiverDisease           0.786676              0.832219
# etio_nonAlcFattyLiver          1.084623              1.051822
# etio_viral                     0.845972              0.867707
# etio_other                     1.146224              1.156681
# sodium                         1.027234              1.035584
# creatinine                     1.029051              0.989735
# CRP                            1.004073                   NaN
# INR                            1.533860                   NaN
# bilirubin                      1.011821                   NaN
# albumin                        1.020380                   NaN
# cps_grp                             NaN              1.106162
# meld                                NaN                   NaN
# pred_bin                       1.142720              1.051452
# hvpg_corrected                      NaN                   NaN
# hvpg_grp                            NaN                   NaN
# AIC                         2262.043022           2265.675882
# Concordance                    0.592386              0.560206
#
#                        survival_radipop+meld  survival_radipop_3g  \
# age                                 1.012854             1.013309
# sex                                 0.768417             0.813743
# etio_alcLiverDisease                0.789249             0.799558
# etio_nonAlcFattyLiver               1.102310             1.117009
# etio_viral                          0.844325             0.899611
# etio_other                          1.117229             1.292190
# sodium                                   NaN             1.028315
# creatinine                               NaN             1.051057
# CRP                                      NaN             1.005613
# INR                                      NaN             1.544529
# bilirubin                                NaN             1.009896
# albumin                             1.026266             1.023677
# cps_grp                                  NaN                  NaN
# meld                                1.035080                  NaN
# pred_bin                            1.052226                  NaN
# hvpg_corrected                           NaN                  NaN
# hvpg_grp                                 NaN                  NaN
# AIC                              2260.262712          2259.287873
# Concordance                         0.578693             0.598229
#
#                        survival_radipop_3g+cps  survival_radipop_3g+meld
# age                                   1.013570                  1.013607
# sex                                   0.846888                  0.787515
# etio_alcLiverDisease                  0.843046                  0.794795
# etio_nonAlcFattyLiver                 1.088427                  1.133781
# etio_viral                            0.918468                  0.889867
# etio_other                            1.300219                  1.260507
# sodium                                1.037772                       NaN
# creatinine                            1.011705                       NaN
# CRP                                        NaN                       NaN
# INR                                        NaN                       NaN
# bilirubin                                  NaN                       NaN
# albumin                                    NaN                  1.029905
# cps_grp                               1.077221                       NaN
# meld                                       NaN                  1.033940
# pred_bin                                   NaN                       NaN
# hvpg_corrected                             NaN                       NaN
# hvpg_grp                                   NaN                       NaN
# AIC                                2263.619827               2258.085046
# Concordance                           0.559339                  0.582139

# %%
results.iloc[:,6:12]
# Out:
#                        survival_measured  survival_measured+cps  \
# age                             1.011964               1.012481
# sex                             0.796398               0.831668
# etio_alcLiverDisease            0.764801               0.814285
# etio_nonAlcFattyLiver           1.057906               1.040912
# etio_viral                      0.831145               0.860763
# etio_other                      1.128972               1.158982
# sodium                          1.027869               1.036109
# creatinine                      1.024197               0.989921
# CRP                             1.007184                    NaN
# INR                             1.512755                    NaN
# bilirubin                       1.011880                    NaN
# albumin                         1.020938                    NaN
# cps_grp                              NaN               1.094208
# meld                                 NaN                    NaN
# pred_bin                             NaN                    NaN
# hvpg_corrected                  1.007651               1.004867
# hvpg_grp                             NaN                    NaN
# AIC                          2262.094723            2265.538416
# Concordance                     0.594669               0.561211
#
#                        survival_measured+meld  survival_meas_grp  \
# age                                  1.012627           1.012548
# sex                                  0.767680           0.809022
# etio_alcLiverDisease                 0.788960           0.733833
# etio_nonAlcFattyLiver                1.097761           1.037793
# etio_viral                           0.840570           0.838414
# etio_other                           1.107047           1.196508
# sodium                                    NaN           1.029402
# creatinine                                NaN           1.036415
# CRP                                       NaN           1.013882
# INR                                       NaN           1.502528
# bilirubin                                 NaN           1.010945
# albumin                              1.025657           1.025127
# cps_grp                                   NaN                NaN
# meld                                 1.035008                NaN
# pred_bin                                  NaN                NaN
# hvpg_corrected                       1.001324                NaN
# hvpg_grp                                  NaN           1.133754
# AIC                               2260.331086        2259.520273
# Concordance                          0.579560           0.601378
#
#                        survival_meas_grp+cps  survival_meas_grp+meld
# age                                 1.012904                1.012703
# sex                                 0.850253                0.786087
# etio_alcLiverDisease                0.784612                0.744284
# etio_nonAlcFattyLiver               1.037704                1.071081
# etio_viral                          0.871677                0.836908
# etio_other                          1.236799                1.174224
# sodium                              1.037959                     NaN
# creatinine                          1.000508                     NaN
# CRP                                      NaN                     NaN
# INR                                      NaN                     NaN
# bilirubin                                NaN                     NaN
# albumin                                  NaN                1.029105
# cps_grp                             1.065318                     NaN
# meld                                     NaN                1.031425
# pred_bin                                 NaN                     NaN
# hvpg_corrected                           NaN                     NaN
# hvpg_grp                            1.113184                1.098525
# AIC                              2263.306490             2258.609822
# Concordance                         0.567395                0.582755

# %%
results.iloc[:,12:18]
# Out:
#                        lrd_radipop  lrd_radipop+cps  lrd_radipop+meld  \
# age                       1.042054         1.038739          1.038351
# sex                       0.958785         1.010056          0.983646
# etio_alcLiverDisease      1.128609         0.985146          1.124600
# etio_nonAlcFattyLiver     0.953645         0.812550          0.972390
# etio_viral                1.033630         0.938444          0.993868
# etio_other                1.305904         1.232801          1.335078
# sodium                    0.984828         0.984553               NaN
# creatinine                0.978913         0.981644               NaN
# CRP                       1.067190              NaN               NaN
# INR                       1.109557              NaN               NaN
# bilirubin                 1.026117              NaN               NaN
# albumin                   0.964733              NaN          0.957720
# cps_grp                        NaN         1.556245               NaN
# meld                           NaN              NaN          1.025605
# pred_bin                  1.413220         1.450094          1.377766
# hvpg_corrected                 NaN              NaN               NaN
# hvpg_grp                       NaN              NaN               NaN
# AIC                    1636.825157      1636.726824       1633.177166
# Concordance               0.646609         0.645440          0.646733
#
#                        lrd_radipop_3g  lrd_radipop_3g+cps  lrd_radipop_3g+meld
# age                          1.040978            1.037937             1.037643
# sex                          0.953976            1.008067             0.983625
# etio_alcLiverDisease         1.155573            1.015945             1.144001
# etio_nonAlcFattyLiver        0.957764            0.818172             0.972287
# etio_viral                   1.056320            0.972220             1.014083
# etio_other                   1.350740            1.298035             1.380705
# sodium                       0.983969            0.983794                  NaN
# creatinine                   0.981220            0.986086                  NaN
# CRP                          1.065811                 NaN                  NaN
# INR                          1.105070                 NaN                  NaN
# bilirubin                    1.026878                 NaN                  NaN
# albumin                      0.962949                 NaN             0.956687
# cps_grp                           NaN            1.581499                  NaN
# meld                              NaN                 NaN             1.027066
# pred_bin                          NaN                 NaN                  NaN
# hvpg_corrected                    NaN                 NaN                  NaN
# hvpg_grp                          NaN                 NaN                  NaN
# AIC                       1637.777372         1637.532272          1633.807398
# Concordance                  0.646087            0.645167             0.645515

# %%
results.iloc[:,18:24]
# Out:
#                        lrd_measured  lrd_measured+cps  lrd_measured+meld  \
# age                        1.039759          1.036021           1.036216
# sex                        0.954849          1.002511           0.980719
# etio_alcLiverDisease       1.033324          0.922067           1.053338
# etio_nonAlcFattyLiver      0.893338          0.778581           0.930944
# etio_viral                 0.982235          0.889596           0.951986
# etio_other                 1.283827          1.205934           1.311574
# sodium                     0.986598          0.985343                NaN
# creatinine                 0.974220          0.978071                NaN
# CRP                        1.075415               NaN                NaN
# INR                        1.075012               NaN                NaN
# bilirubin                  1.027097               NaN                NaN
# albumin                    0.968463               NaN           0.958580
# cps_grp                         NaN          1.516468                NaN
# meld                            NaN               NaN           1.022883
# pred_bin                        NaN               NaN                NaN
# hvpg_corrected             1.021688          1.019023           1.017288
# hvpg_grp                        NaN               NaN                NaN
# AIC                     1635.732044       1636.740289        1632.988064
# Concordance                0.648224          0.647230           0.645540
#
#                        lrd_meas_grp  lrd_meas_grp+cps  lrd_meas_grp+meld
# age                        1.041224          1.037581           1.037392
# sex                        0.987462          1.032729           1.007914
# etio_alcLiverDisease       1.077605          0.938669           1.089771
# etio_nonAlcFattyLiver      0.919119          0.794186           0.955390
# etio_viral                 1.034268          0.928352           0.993053
# etio_other                 1.370470          1.278397           1.391424
# sodium                     0.985859          0.984842                NaN
# creatinine                 0.970071          0.976403                NaN
# CRP                        1.073552               NaN                NaN
# INR                        1.058840               NaN                NaN
# bilirubin                  1.028008               NaN                NaN
# albumin                    0.966818               NaN           0.957615
# cps_grp                         NaN          1.527551                NaN
# meld                            NaN               NaN           1.022592
# pred_bin                        NaN               NaN                NaN
# hvpg_corrected                  NaN               NaN                NaN
# hvpg_grp                   1.190178          1.180682           1.154113
# AIC                     1635.459420       1636.014428        1632.712616
# Concordance                0.645614          0.643253           0.640966

# %%
results.iloc[:,[36,42]]
# Out:
#                        lre_radipop  lre_measured
# age                       1.005795      1.000728
# sex                       0.783936      0.794035
# etio_alcLiverDisease      1.275799      0.996759
# etio_nonAlcFattyLiver     1.734253      1.423962
# etio_viral                0.561203      0.495510
# etio_other                1.217435      1.109078
# sodium                    0.938613      0.944419
# creatinine                1.611050      1.598611
# CRP                       1.012455      1.029438
# INR                       1.321065      1.273778
# bilirubin                 0.987115      0.988034
# albumin                   0.933642      0.940719
# cps_grp                        NaN           NaN
# meld                           NaN           NaN
# pred_bin                  2.338185           NaN
# hvpg_corrected                 NaN      1.048537
# hvpg_grp                       NaN           NaN
# AIC                    2738.943810   2732.678241
# Concordance               0.754538      0.760480

# %%
# univariable
allCov = ['age', 'sex',
          'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
          'sodium', 'creatinine', 'CRP', 'bilirubin', 'albumin', 'INR', 
          'cps_grp', 'meld',
          'pred_bin', 'hvpg_grp', 'hvpg_corrected']

uniResults = {}
uni_df = pd.DataFrame()

for eaTuple in timetuples:
    for eaCov in allCov:
        temp = currMeta[[eaCov, eaTuple[0], eaTuple[1]]]
        cph = CoxPHFitter()
        cph.fit(temp, duration_col = eaTuple[0], event_col = eaTuple[1])
        
        uniResults[eaCov] = cph.hazard_ratios_[0]
    curr_df = pd.DataFrame.from_dict(uniResults,
                                     orient='index',
                                     columns=[eaTuple[0]])
    uni_df = pd.merge(uni_df, curr_df, how='outer', left_index=True, right_index=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# /opt/conda/lib/python3.7/site-packages/lifelines/utils/__init__.py:1187: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)

# %%
uni_df
# Out:
#                        survival       lrd       tfs       lre
# age                    1.013560  1.027362  1.029302  0.994748
# sex                    0.836632  1.020161  1.153647  0.865154
# etio_alcLiverDisease   0.843119  1.305123  1.304863  2.051225
# etio_nonAlcFattyLiver  1.329849  0.940253  0.966720  1.230994
# etio_viral             0.870641  0.666933  0.626306  0.360535
# etio_other             1.310350  1.105786  1.159843  0.913748
# sodium                 1.039959  0.962722  0.947906  0.907399
# creatinine             0.996582  1.069226  1.073425  1.442071
# CRP                    0.978108  1.085017  1.088752  1.093222
# bilirubin              1.012834  1.042471  1.055771  1.062785
# albumin                1.014811  0.953222  0.944839  0.905525
# INR                    1.366665  1.392716  1.580738  1.805527
# cps_grp                0.991733  1.488664  1.623391  3.177756
# meld                   1.012765  1.040497  1.051742  1.097122
# pred_bin               0.904992  1.556983  1.615531  3.366925
# hvpg_grp               1.029376  1.236768  1.262643  1.756352
# hvpg_corrected         0.997334  1.031916  1.034925  1.068345

# %%
shortResults_cont = pd.merge(results, uni_df['survival'], how='outer', left_index=True, right_index=True)

# reorder columns
orderIndex = ['survival',
              'survival_radipop', 'survival_measured',
              'survival_radipop+cps', 'survival_measured+cps',
              'survival_radipop+meld', 'survival_measured+meld'
             ]
shortResults_cont = shortResults_cont[orderIndex]
shortResults_cont = shortResults_cont.rename(columns={'survival':'univariable'})

# reorder rows
orderIndex = ['age', 'sex',
              'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
              'sodium', 'creatinine', 'CRP', 'INR', 'bilirubin', 'albumin',
              'cps_grp', 'meld',
              'pred_bin', 'hvpg_corrected', 'hvpg_grp',
              'AIC', 'Concordance'
             ]
shortResults_cont = shortResults_cont.reindex(orderIndex)

shortResults_cont
# Out:
#                        univariable  survival_radipop  survival_measured  \
# age                       1.013560          1.012693           1.011964
# sex                       0.836632          0.795326           0.796398
# etio_alcLiverDisease      0.843119          0.786676           0.764801
# etio_nonAlcFattyLiver     1.329849          1.084623           1.057906
# etio_viral                0.870641          0.845972           0.831145
# etio_other                1.310350          1.146224           1.128972
# sodium                    1.039959          1.027234           1.027869
# creatinine                0.996582          1.029051           1.024197
# CRP                       0.978108          1.004073           1.007184
# INR                       1.366665          1.533860           1.512755
# bilirubin                 1.012834          1.011821           1.011880
# albumin                   1.014811          1.020380           1.020938
# cps_grp                   0.991733               NaN                NaN
# meld                      1.012765               NaN                NaN
# pred_bin                  0.904992          1.142720                NaN
# hvpg_corrected            0.997334               NaN           1.007651
# hvpg_grp                  1.029376               NaN                NaN
# AIC                            NaN       2262.043022        2262.094723
# Concordance                    NaN          0.592386           0.594669
#
#                        survival_radipop+cps  survival_measured+cps  \
# age                                1.012897               1.012481
# sex                                0.829939               0.831668
# etio_alcLiverDisease               0.832219               0.814285
# etio_nonAlcFattyLiver              1.051822               1.040912
# etio_viral                         0.867707               0.860763
# etio_other                         1.156681               1.158982
# sodium                             1.035584               1.036109
# creatinine                         0.989735               0.989921
# CRP                                     NaN                    NaN
# INR                                     NaN                    NaN
# bilirubin                               NaN                    NaN
# albumin                                 NaN                    NaN
# cps_grp                            1.106162               1.094208
# meld                                    NaN                    NaN
# pred_bin                           1.051452                    NaN
# hvpg_corrected                          NaN               1.004867
# hvpg_grp                                NaN                    NaN
# AIC                             2265.675882            2265.538416
# Concordance                        0.560206               0.561211
#
#                        survival_radipop+meld  survival_measured+meld
# age                                 1.012854                1.012627
# sex                                 0.768417                0.767680
# etio_alcLiverDisease                0.789249                0.788960
# etio_nonAlcFattyLiver               1.102310                1.097761
# etio_viral                          0.844325                0.840570
# etio_other                          1.117229                1.107047
# sodium                                   NaN                     NaN
# creatinine                               NaN                     NaN
# CRP                                      NaN                     NaN
# INR                                      NaN                     NaN
# bilirubin                                NaN                     NaN
# albumin                             1.026266                1.025657
# cps_grp                                  NaN                     NaN
# meld                                1.035080                1.035008
# pred_bin                            1.052226                     NaN
# hvpg_corrected                           NaN                1.001324
# hvpg_grp                                 NaN                     NaN
# AIC                              2260.262712             2260.331086
# Concordance                         0.578693                0.579560

# %%
import zentables as zen
shortResults_cont.zen.pretty()
# Out:
# <style type="text/css">
# </style>
#
#
#
# <table id="T_649f5_" style="border-collapse: collapse; font-size: Arial, Helvetica, sans-serif; font-family: 11pt">
#
#
#
#
#
# <thead>
#
#
#
#     <tr style="padding: 0; margin: 0;">
#
#
#
#       <th class="blank level0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >&nbsp;</th>
#
#
#
#       <th class="col_heading level0 col0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >univariable</th>
#
#
#
#       <th class="col_heading level0 col1"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop</th>
#
#
#
#       <th class="col_heading level0 col2"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured</th>
#
#
#
#       <th class="col_heading level0 col3"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop+cps</th>
#
#
#
#       <th class="col_heading level0 col4"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured+cps</th>
#
#
#
#       <th class="col_heading level0 col5"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop+meld</th>
#
#
#
#       <th class="col_heading level0 col6"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured+meld</th>
#
#
#
#     </tr>
#
#
#
# </thead>
#
#
# <tbody>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row0" class="row_heading level0 row0"  style="vertical-align: middle; text-align: left" >age</th>
#
#       <td id="T_649f5_row0_col0" class="data row0 col0"  style="vertical-align: middle; text-align: center" >1.013560</td>
#
#       <td id="T_649f5_row0_col1" class="data row0 col1"  style="vertical-align: middle; text-align: center" >1.012693</td>
#
#       <td id="T_649f5_row0_col2" class="data row0 col2"  style="vertical-align: middle; text-align: center" >1.011964</td>
#
#       <td id="T_649f5_row0_col3" class="data row0 col3"  style="vertical-align: middle; text-align: center" >1.012897</td>
#
#       <td id="T_649f5_row0_col4" class="data row0 col4"  style="vertical-align: middle; text-align: center" >1.012481</td>
#
#       <td id="T_649f5_row0_col5" class="data row0 col5"  style="vertical-align: middle; text-align: center" >1.012854</td>
#
#       <td id="T_649f5_row0_col6" class="data row0 col6"  style="vertical-align: middle; text-align: center" >1.012627</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row1" class="row_heading level0 row1"  style="vertical-align: middle; text-align: left" >sex</th>
#
#       <td id="T_649f5_row1_col0" class="data row1 col0"  style="vertical-align: middle; text-align: center" >0.836632</td>
#
#       <td id="T_649f5_row1_col1" class="data row1 col1"  style="vertical-align: middle; text-align: center" >0.795326</td>
#
#       <td id="T_649f5_row1_col2" class="data row1 col2"  style="vertical-align: middle; text-align: center" >0.796398</td>
#
#       <td id="T_649f5_row1_col3" class="data row1 col3"  style="vertical-align: middle; text-align: center" >0.829939</td>
#
#       <td id="T_649f5_row1_col4" class="data row1 col4"  style="vertical-align: middle; text-align: center" >0.831668</td>
#
#       <td id="T_649f5_row1_col5" class="data row1 col5"  style="vertical-align: middle; text-align: center" >0.768417</td>
#
#       <td id="T_649f5_row1_col6" class="data row1 col6"  style="vertical-align: middle; text-align: center" >0.767680</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row2" class="row_heading level0 row2"  style="vertical-align: middle; text-align: left" >etio_alcLiverDisease</th>
#
#       <td id="T_649f5_row2_col0" class="data row2 col0"  style="vertical-align: middle; text-align: center" >0.843119</td>
#
#       <td id="T_649f5_row2_col1" class="data row2 col1"  style="vertical-align: middle; text-align: center" >0.786676</td>
#
#       <td id="T_649f5_row2_col2" class="data row2 col2"  style="vertical-align: middle; text-align: center" >0.764801</td>
#
#       <td id="T_649f5_row2_col3" class="data row2 col3"  style="vertical-align: middle; text-align: center" >0.832219</td>
#
#       <td id="T_649f5_row2_col4" class="data row2 col4"  style="vertical-align: middle; text-align: center" >0.814285</td>
#
#       <td id="T_649f5_row2_col5" class="data row2 col5"  style="vertical-align: middle; text-align: center" >0.789249</td>
#
#       <td id="T_649f5_row2_col6" class="data row2 col6"  style="vertical-align: middle; text-align: center" >0.788960</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row3" class="row_heading level0 row3"  style="vertical-align: middle; text-align: left" >etio_nonAlcFattyLiver</th>
#
#       <td id="T_649f5_row3_col0" class="data row3 col0"  style="vertical-align: middle; text-align: center" >1.329849</td>
#
#       <td id="T_649f5_row3_col1" class="data row3 col1"  style="vertical-align: middle; text-align: center" >1.084623</td>
#
#       <td id="T_649f5_row3_col2" class="data row3 col2"  style="vertical-align: middle; text-align: center" >1.057906</td>
#
#       <td id="T_649f5_row3_col3" class="data row3 col3"  style="vertical-align: middle; text-align: center" >1.051822</td>
#
#       <td id="T_649f5_row3_col4" class="data row3 col4"  style="vertical-align: middle; text-align: center" >1.040912</td>
#
#       <td id="T_649f5_row3_col5" class="data row3 col5"  style="vertical-align: middle; text-align: center" >1.102310</td>
#
#       <td id="T_649f5_row3_col6" class="data row3 col6"  style="vertical-align: middle; text-align: center" >1.097761</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row4" class="row_heading level0 row4"  style="vertical-align: middle; text-align: left" >etio_viral</th>
#
#       <td id="T_649f5_row4_col0" class="data row4 col0"  style="vertical-align: middle; text-align: center" >0.870641</td>
#
#       <td id="T_649f5_row4_col1" class="data row4 col1"  style="vertical-align: middle; text-align: center" >0.845972</td>
#
#       <td id="T_649f5_row4_col2" class="data row4 col2"  style="vertical-align: middle; text-align: center" >0.831145</td>
#
#       <td id="T_649f5_row4_col3" class="data row4 col3"  style="vertical-align: middle; text-align: center" >0.867707</td>
#
#       <td id="T_649f5_row4_col4" class="data row4 col4"  style="vertical-align: middle; text-align: center" >0.860763</td>
#
#       <td id="T_649f5_row4_col5" class="data row4 col5"  style="vertical-align: middle; text-align: center" >0.844325</td>
#
#       <td id="T_649f5_row4_col6" class="data row4 col6"  style="vertical-align: middle; text-align: center" >0.840570</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_649f5_level0_row5" class="row_heading level0 row5"  style="vertical-align: middle; text-align: left" >etio_other</th>
#
#       <td id="T_649f5_row5_col0" class="data row5 col0"  style="vertical-align: middle; text-align: center" >1.310350</td>
#
#       <td id="T_649f5_row5_col1" class="data row5 col1"  style="vertical-align: middle; text-align: center" >1.146224</td>
#
#       <td id="T_649f5_row5_col2" class="data row5 col2"  style="vertical-align: middle; text-align: center" >1.128972</td>
#
#       <td id="T_649f5_row5_col3" class="data row5 col3"  style="vertical-align: middle; text-align: center" >1.156681</td>
#
#       <td id="T_649f5_row5_col4" class="data row5 col4"  style="vertical-align: middle; text-align: center" >1.158982</td>
#
#       <td id="T_649f5_row5_col5" class="data row5 col5"  style="vertical-align: middle; text-align: center" >1.117229</td>
#
#       <td id="T_649f5_row5_col6" class="data row5 col6"  style="vertical-align: middle; text-align

# %%
shortResults_cont = pd.merge(results, uni_df['survival'], how='outer', left_index=True, right_index=True)

# reorder columns
orderIndex = ['survival',
              'survival_radipop_3g', 'survival_measured',
              'survival_radipop_3g+cps', 'survival_measured+cps',
              'survival_radipop_3g+meld', 'survival_measured+meld'
             ]
shortResults_cont = shortResults_cont[orderIndex]
shortResults_cont = shortResults_cont.rename(columns={'survival':'univariable'})

# reorder rows
orderIndex = ['age', 'sex',
              'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
              'sodium', 'creatinine', 'CRP', 'INR', 'bilirubin', 'albumin',
              'cps_grp', 'meld',
              'pred_bin', 'hvpg_corrected', 'hvpg_grp',
              'AIC', 'Concordance'
             ]
shortResults_cont = shortResults_cont.reindex(orderIndex)

shortResults_cont.zen.pretty()
# Out:
# <style type="text/css">
# </style>
#
#
#
# <table id="T_e9b4f_" style="border-collapse: collapse; font-size: Arial, Helvetica, sans-serif; font-family: 11pt">
#
#
#
#
#
# <thead>
#
#
#
#     <tr style="padding: 0; margin: 0;">
#
#
#
#       <th class="blank level0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >&nbsp;</th>
#
#
#
#       <th class="col_heading level0 col0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >univariable</th>
#
#
#
#       <th class="col_heading level0 col1"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop_3g</th>
#
#
#
#       <th class="col_heading level0 col2"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured</th>
#
#
#
#       <th class="col_heading level0 col3"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop_3g+cps</th>
#
#
#
#       <th class="col_heading level0 col4"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured+cps</th>
#
#
#
#       <th class="col_heading level0 col5"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop_3g+meld</th>
#
#
#
#       <th class="col_heading level0 col6"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_measured+meld</th>
#
#
#
#     </tr>
#
#
#
# </thead>
#
#
# <tbody>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row0" class="row_heading level0 row0"  style="vertical-align: middle; text-align: left" >age</th>
#
#       <td id="T_e9b4f_row0_col0" class="data row0 col0"  style="vertical-align: middle; text-align: center" >1.013560</td>
#
#       <td id="T_e9b4f_row0_col1" class="data row0 col1"  style="vertical-align: middle; text-align: center" >1.013309</td>
#
#       <td id="T_e9b4f_row0_col2" class="data row0 col2"  style="vertical-align: middle; text-align: center" >1.011964</td>
#
#       <td id="T_e9b4f_row0_col3" class="data row0 col3"  style="vertical-align: middle; text-align: center" >1.013570</td>
#
#       <td id="T_e9b4f_row0_col4" class="data row0 col4"  style="vertical-align: middle; text-align: center" >1.012481</td>
#
#       <td id="T_e9b4f_row0_col5" class="data row0 col5"  style="vertical-align: middle; text-align: center" >1.013607</td>
#
#       <td id="T_e9b4f_row0_col6" class="data row0 col6"  style="vertical-align: middle; text-align: center" >1.012627</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row1" class="row_heading level0 row1"  style="vertical-align: middle; text-align: left" >sex</th>
#
#       <td id="T_e9b4f_row1_col0" class="data row1 col0"  style="vertical-align: middle; text-align: center" >0.836632</td>
#
#       <td id="T_e9b4f_row1_col1" class="data row1 col1"  style="vertical-align: middle; text-align: center" >0.813743</td>
#
#       <td id="T_e9b4f_row1_col2" class="data row1 col2"  style="vertical-align: middle; text-align: center" >0.796398</td>
#
#       <td id="T_e9b4f_row1_col3" class="data row1 col3"  style="vertical-align: middle; text-align: center" >0.846888</td>
#
#       <td id="T_e9b4f_row1_col4" class="data row1 col4"  style="vertical-align: middle; text-align: center" >0.831668</td>
#
#       <td id="T_e9b4f_row1_col5" class="data row1 col5"  style="vertical-align: middle; text-align: center" >0.787515</td>
#
#       <td id="T_e9b4f_row1_col6" class="data row1 col6"  style="vertical-align: middle; text-align: center" >0.767680</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row2" class="row_heading level0 row2"  style="vertical-align: middle; text-align: left" >etio_alcLiverDisease</th>
#
#       <td id="T_e9b4f_row2_col0" class="data row2 col0"  style="vertical-align: middle; text-align: center" >0.843119</td>
#
#       <td id="T_e9b4f_row2_col1" class="data row2 col1"  style="vertical-align: middle; text-align: center" >0.799558</td>
#
#       <td id="T_e9b4f_row2_col2" class="data row2 col2"  style="vertical-align: middle; text-align: center" >0.764801</td>
#
#       <td id="T_e9b4f_row2_col3" class="data row2 col3"  style="vertical-align: middle; text-align: center" >0.843046</td>
#
#       <td id="T_e9b4f_row2_col4" class="data row2 col4"  style="vertical-align: middle; text-align: center" >0.814285</td>
#
#       <td id="T_e9b4f_row2_col5" class="data row2 col5"  style="vertical-align: middle; text-align: center" >0.794795</td>
#
#       <td id="T_e9b4f_row2_col6" class="data row2 col6"  style="vertical-align: middle; text-align: center" >0.788960</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row3" class="row_heading level0 row3"  style="vertical-align: middle; text-align: left" >etio_nonAlcFattyLiver</th>
#
#       <td id="T_e9b4f_row3_col0" class="data row3 col0"  style="vertical-align: middle; text-align: center" >1.329849</td>
#
#       <td id="T_e9b4f_row3_col1" class="data row3 col1"  style="vertical-align: middle; text-align: center" >1.117009</td>
#
#       <td id="T_e9b4f_row3_col2" class="data row3 col2"  style="vertical-align: middle; text-align: center" >1.057906</td>
#
#       <td id="T_e9b4f_row3_col3" class="data row3 col3"  style="vertical-align: middle; text-align: center" >1.088427</td>
#
#       <td id="T_e9b4f_row3_col4" class="data row3 col4"  style="vertical-align: middle; text-align: center" >1.040912</td>
#
#       <td id="T_e9b4f_row3_col5" class="data row3 col5"  style="vertical-align: middle; text-align: center" >1.133781</td>
#
#       <td id="T_e9b4f_row3_col6" class="data row3 col6"  style="vertical-align: middle; text-align: center" >1.097761</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row4" class="row_heading level0 row4"  style="vertical-align: middle; text-align: left" >etio_viral</th>
#
#       <td id="T_e9b4f_row4_col0" class="data row4 col0"  style="vertical-align: middle; text-align: center" >0.870641</td>
#
#       <td id="T_e9b4f_row4_col1" class="data row4 col1"  style="vertical-align: middle; text-align: center" >0.899611</td>
#
#       <td id="T_e9b4f_row4_col2" class="data row4 col2"  style="vertical-align: middle; text-align: center" >0.831145</td>
#
#       <td id="T_e9b4f_row4_col3" class="data row4 col3"  style="vertical-align: middle; text-align: center" >0.918468</td>
#
#       <td id="T_e9b4f_row4_col4" class="data row4 col4"  style="vertical-align: middle; text-align: center" >0.860763</td>
#
#       <td id="T_e9b4f_row4_col5" class="data row4 col5"  style="vertical-align: middle; text-align: center" >0.889867</td>
#
#       <td id="T_e9b4f_row4_col6" class="data row4 col6"  style="vertical-align: middle; text-align: center" >0.840570</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e9b4f_level0_row5" class="row_heading level0 row5"  style="vertical-align: middle; text-align: left" >etio_other</th>
#
#       <td id="T_e9b4f_row5_col0" class="data row5 col0"  style="vertical-align: middle; text-align: center" >1.310350</td>
#
#       <td id="T_e9b4f_row5_col1" class="data row5 col1"  style="vertical-align: middle; text-align: center" >1.292190</td>
#
#       <td id="T_e9b4f_row5_col2" class="data row5 col2"  style="vertical-align: middle; text-align: center" >1.128972</td>
#
#       <td id="T_e9b4f_row5_col3" class="data row5 col3"  style="vertical-align: middle; text-align: center" >1.300219</td>
#
#       <td id="T_e9b4f_row5_col4" class="data row5 col4"  style="vertical-align: middle; text-align: center" >1.158982</td>
#
#       <td id="T_e9b4f_row5_col5" class="data row5 col5"  style="vertical-align: middle; text-align: center" >1.260507</td>
#
#       <td id="T_e9b4f_row5_col6" class="data row5 col6"  style="vertical-align: middle; t

# %%
shortResults_cont = pd.merge(results, uni_df['survival'], how='outer', left_index=True, right_index=True)

# reorder columns
orderIndex = ['survival',
              'survival_radipop', 'survival_meas_grp',
              'survival_radipop+cps', 'survival_meas_grp+cps',
              'survival_radipop+meld', 'survival_meas_grp+meld'
             ]
shortResults_cont = shortResults_cont[orderIndex]
shortResults_cont = shortResults_cont.rename(columns={'survival':'univariable'})

# reorder rows
orderIndex = ['age', 'sex',
              'etio_alcLiverDisease', 'etio_nonAlcFattyLiver', 'etio_viral', 'etio_other',
              'sodium', 'creatinine', 'CRP', 'INR', 'bilirubin', 'albumin',
              'cps_grp', 'meld',
              'pred_bin', 'hvpg_corrected', 'hvpg_grp',
              'AIC', 'Concordance'
             ]
shortResults_cont = shortResults_cont.reindex(orderIndex)

shortResults_cont.zen.pretty()
# Out:
# <style type="text/css">
# </style>
#
#
#
# <table id="T_e1c7c_" style="border-collapse: collapse; font-size: Arial, Helvetica, sans-serif; font-family: 11pt">
#
#
#
#
#
# <thead>
#
#
#
#     <tr style="padding: 0; margin: 0;">
#
#
#
#       <th class="blank level0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >&nbsp;</th>
#
#
#
#       <th class="col_heading level0 col0"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >univariable</th>
#
#
#
#       <th class="col_heading level0 col1"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop</th>
#
#
#
#       <th class="col_heading level0 col2"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_meas_grp</th>
#
#
#
#       <th class="col_heading level0 col3"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop+cps</th>
#
#
#
#       <th class="col_heading level0 col4"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_meas_grp+cps</th>
#
#
#
#       <th class="col_heading level0 col5"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_radipop+meld</th>
#
#
#
#       <th class="col_heading level0 col6"  style="text-align: center; border-top: 1.5pt solid black; border-bottom: 1.5pt solid black" >survival_meas_grp+meld</th>
#
#
#
#     </tr>
#
#
#
# </thead>
#
#
# <tbody>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row0" class="row_heading level0 row0"  style="vertical-align: middle; text-align: left" >age</th>
#
#       <td id="T_e1c7c_row0_col0" class="data row0 col0"  style="vertical-align: middle; text-align: center" >1.013560</td>
#
#       <td id="T_e1c7c_row0_col1" class="data row0 col1"  style="vertical-align: middle; text-align: center" >1.012693</td>
#
#       <td id="T_e1c7c_row0_col2" class="data row0 col2"  style="vertical-align: middle; text-align: center" >1.012548</td>
#
#       <td id="T_e1c7c_row0_col3" class="data row0 col3"  style="vertical-align: middle; text-align: center" >1.012897</td>
#
#       <td id="T_e1c7c_row0_col4" class="data row0 col4"  style="vertical-align: middle; text-align: center" >1.012904</td>
#
#       <td id="T_e1c7c_row0_col5" class="data row0 col5"  style="vertical-align: middle; text-align: center" >1.012854</td>
#
#       <td id="T_e1c7c_row0_col6" class="data row0 col6"  style="vertical-align: middle; text-align: center" >1.012703</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row1" class="row_heading level0 row1"  style="vertical-align: middle; text-align: left" >sex</th>
#
#       <td id="T_e1c7c_row1_col0" class="data row1 col0"  style="vertical-align: middle; text-align: center" >0.836632</td>
#
#       <td id="T_e1c7c_row1_col1" class="data row1 col1"  style="vertical-align: middle; text-align: center" >0.795326</td>
#
#       <td id="T_e1c7c_row1_col2" class="data row1 col2"  style="vertical-align: middle; text-align: center" >0.809022</td>
#
#       <td id="T_e1c7c_row1_col3" class="data row1 col3"  style="vertical-align: middle; text-align: center" >0.829939</td>
#
#       <td id="T_e1c7c_row1_col4" class="data row1 col4"  style="vertical-align: middle; text-align: center" >0.850253</td>
#
#       <td id="T_e1c7c_row1_col5" class="data row1 col5"  style="vertical-align: middle; text-align: center" >0.768417</td>
#
#       <td id="T_e1c7c_row1_col6" class="data row1 col6"  style="vertical-align: middle; text-align: center" >0.786087</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row2" class="row_heading level0 row2"  style="vertical-align: middle; text-align: left" >etio_alcLiverDisease</th>
#
#       <td id="T_e1c7c_row2_col0" class="data row2 col0"  style="vertical-align: middle; text-align: center" >0.843119</td>
#
#       <td id="T_e1c7c_row2_col1" class="data row2 col1"  style="vertical-align: middle; text-align: center" >0.786676</td>
#
#       <td id="T_e1c7c_row2_col2" class="data row2 col2"  style="vertical-align: middle; text-align: center" >0.733833</td>
#
#       <td id="T_e1c7c_row2_col3" class="data row2 col3"  style="vertical-align: middle; text-align: center" >0.832219</td>
#
#       <td id="T_e1c7c_row2_col4" class="data row2 col4"  style="vertical-align: middle; text-align: center" >0.784612</td>
#
#       <td id="T_e1c7c_row2_col5" class="data row2 col5"  style="vertical-align: middle; text-align: center" >0.789249</td>
#
#       <td id="T_e1c7c_row2_col6" class="data row2 col6"  style="vertical-align: middle; text-align: center" >0.744284</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row3" class="row_heading level0 row3"  style="vertical-align: middle; text-align: left" >etio_nonAlcFattyLiver</th>
#
#       <td id="T_e1c7c_row3_col0" class="data row3 col0"  style="vertical-align: middle; text-align: center" >1.329849</td>
#
#       <td id="T_e1c7c_row3_col1" class="data row3 col1"  style="vertical-align: middle; text-align: center" >1.084623</td>
#
#       <td id="T_e1c7c_row3_col2" class="data row3 col2"  style="vertical-align: middle; text-align: center" >1.037793</td>
#
#       <td id="T_e1c7c_row3_col3" class="data row3 col3"  style="vertical-align: middle; text-align: center" >1.051822</td>
#
#       <td id="T_e1c7c_row3_col4" class="data row3 col4"  style="vertical-align: middle; text-align: center" >1.037704</td>
#
#       <td id="T_e1c7c_row3_col5" class="data row3 col5"  style="vertical-align: middle; text-align: center" >1.102310</td>
#
#       <td id="T_e1c7c_row3_col6" class="data row3 col6"  style="vertical-align: middle; text-align: center" >1.071081</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row4" class="row_heading level0 row4"  style="vertical-align: middle; text-align: left" >etio_viral</th>
#
#       <td id="T_e1c7c_row4_col0" class="data row4 col0"  style="vertical-align: middle; text-align: center" >0.870641</td>
#
#       <td id="T_e1c7c_row4_col1" class="data row4 col1"  style="vertical-align: middle; text-align: center" >0.845972</td>
#
#       <td id="T_e1c7c_row4_col2" class="data row4 col2"  style="vertical-align: middle; text-align: center" >0.838414</td>
#
#       <td id="T_e1c7c_row4_col3" class="data row4 col3"  style="vertical-align: middle; text-align: center" >0.867707</td>
#
#       <td id="T_e1c7c_row4_col4" class="data row4 col4"  style="vertical-align: middle; text-align: center" >0.871677</td>
#
#       <td id="T_e1c7c_row4_col5" class="data row4 col5"  style="vertical-align: middle; text-align: center" >0.844325</td>
#
#       <td id="T_e1c7c_row4_col6" class="data row4 col6"  style="vertical-align: middle; text-align: center" >0.836908</td>
#
#
#     </tr>
#
#
#
#     <tr style="background-color: white; padding: 0; margin: 0;">
#
#
#       <th id="T_e1c7c_level0_row5" class="row_heading level0 row5"  style="vertical-align: middle; text-align: left" >etio_other</th>
#
#       <td id="T_e1c7c_row5_col0" class="data row5 col0"  style="vertical-align: middle; text-align: center" >1.310350</td>
#
#       <td id="T_e1c7c_row5_col1" class="data row5 col1"  style="vertical-align: middle; text-align: center" >1.146224</td>
#
#       <td id="T_e1c7c_row5_col2" class="data row5 col2"  style="vertical-align: middle; text-align: center" >1.196508</td>
#
#       <td id="T_e1c7c_row5_col3" class="data row5 col3"  style="vertical-align: middle; text-align: center" >1.156681</td>
#
#       <td id="T_e1c7c_row5_col4" class="data row5 col4"  style="vertical-align: middle; text-align: center" >1.236799</td>
#
#       <td id="T_e1c7c_row5_col5" class="data row5 col5"  style="vertical-align: middle; text-align: center" >1.117229</td>
#
#       <td id="T_e1c7c_row5_col6" class="data row5 col6"  style="vertical-align: middle; text-align

# %%
print(datetime.datetime.now())
# Out:
# 2023-01-17 10:21:19.343662
